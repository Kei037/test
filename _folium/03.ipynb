# %% [markdown]
# # 03. 지도에 마커 표시하기

# %%
# 서울 시내 주요 대학교의 위치 데이터를 데이터 프레임으로 변환하고, folium 지도에 위치를 표시.

# %%
import pandas as pd
import folium

# %%
# 대학교 리스트를 데이터프레임 변환
df = pd.read_excel('./input/서울지역 대학교 위치.xlsx')
df.head()
# Out:
#            name         위도          경도
# 0  KAIST 서울캠퍼스   37.592573  127.046737
# 1         KC대학교  37.548345  126.854797
# 2  가톨릭대학교(성신교정)  37.585922  127.004328
# 3  가톨릭대학교(성의교정)  37.499623  127.006065
# 4      감리교신학대학교  37.567645  126.961610

# %%
# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55, 126.98], zoom_start=12)

# %%
# 대학교 위치정보를 Marker로 표시
for name, lat, lng in zip(df['name'], df['위도'], df['경도']):
    folium.Marker([lat, lng], popup=name).add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_171c1c8a44525993c50cf0bfcd3d7dff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_171c1c8a44525993c50cf0bfcd3d7dff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_171c1c8a44525993c50cf0bfcd3d7dff = L.map(
#                 &quot;map_171c1c8a44525993c50cf0bfcd3d7dff&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d1d134802d93483ec42759354029dd9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_171c1c8a44525993c50cf0bfcd3d7dff);
#
#
#             var marker_fd1b0b489b8b8c2a8984cb600b0655fc = L.marker(
#                 [37.592573, 127.046737],
#                 {}
#             ).addTo(map_171c1c8a44525993c50cf0bfcd3d7dff);
#
#
#         var popup_b3fb03519168fca29b52a761d29e8a4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c923f648b028f6ea87432b5a6384e311 = $(`&lt;div id=&quot;html_c923f648b028f6ea87432b5a6384e311&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KAIST 서울캠퍼스 &lt;/div&gt;`)[0];
#                 popup_b3fb03519168fca29b52a761d29e8a4c.setContent(html_c923f648b028f6ea87432b5a6384e311);
#
#
#
#         marker_fd1b0b489b8b8c2a8984cb600b0655fc.bindPopup(popup_b3fb03519168fca29b52a761d29e8a4c)
#         ;
#
#
#
#
#             var marker_9bc40a7585e9fe914dc4d37f3d075739 = L.marker(
#                 [37.5483449, 126.8547974],
#                 {}
#             ).addTo(map_171c1c8a44525993c50cf0bfcd3d7dff);
#
#
#         var popup_493a57346f61aeffd2be4231d4119e57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67dbe48e431b10eeea61c9443a62590b = $(`&lt;div id=&quot;html_67dbe48e431b10eeea61c9443a62590b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KC대학교&lt;/div&gt;`)[0];
#                 popup_493a57346f61aeffd2be4231d4119e57.setContent(html_67dbe48e431b10eeea61c9443a62590b);
#
#
#
#         marker_9bc40a7585e9fe914dc4d37f3d075739.bindPopup(popup_493a57346f61aeffd2be4231d4119e57)
#         ;
#
#
#
#
#             var marker_66db22914a6f22df2b761d114ea3e02e = L.marker(
#                 [37.5859218, 127.0043275],
#                 {}
#             ).addTo(map_171c1c8a44525993c50cf0bfcd3d7dff);
#
#
#         var popup_62cb7e6c0bc941f2e9ea94706c3a9608 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_efe76c0c5bee3a84d5564f3dc253e0b0 = $(`&lt;div id=&quot;html_efe76c0c5bee3a84d5564f3dc253e0b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성신교정)&lt;/div&gt;`)[0];
#                 popup_62cb7e6c0bc941f2e9ea94706c3a9608.setContent(html_efe76c0c5bee3a84d5564f3dc253e0b0);
#
#
#
#         marker_66db22914a6f22df2b761d114ea3e02e.bindPopup(popup_62cb7e6c0bc941f2e9ea94706c3a9608)
#         ;
#
#
#
#
#             var marker_813c67c0819df5f3b1aee10ead4a32f9 = L.marker(
#                 [37.4996227, 127.0060653],
#                 {}
#             ).addTo(map_171c1c8a44525993c50cf0bfcd3d7dff);
#
#
#         var popup_429cfc5f76875df502e60c08e9aa23c5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0653eaebff8f946413123a6f6284b535 = $(`&lt;div id=&quot;html_0653eaebff8f946413123a6f6284b535&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가톨릭대학교(성의교정)&lt;/div&gt;`)[0];
#                 popup_429cfc5f76875df502e60c08e9aa23c5.setContent(html_0653eaebff8f946413123a6f6284b535);
#
#
#
#         marker_813c67c0819df5f3b1aee10ead4a32f9.bindPopup(popup_429cfc5f76875df502e60c08e9aa23c5)
#         ;
#
#
#
#
#             var marker_8ab9824194bd7211c4946ac2df7e4bdf = L.marker(
#                 [37.5676455, 126.96161],
#                 {}
#             ).addTo(map_171c1c8a44525993c50cf0bfcd3d7dff);
#
#
#         var popup_f5fc89f2634050376fbfb20f81d3f3de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1afb31bb700af66868d99937aedfe763 = $(`&lt;div id=&quot;html_1afb31bb700af66868d99937aedfe763&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;감리교신학대학교&lt;/div&gt;`)[0];
#                 popup_f5fc89f2634050376fbfb20f81d3f3de.setContent(html_1afb31bb700af66868d99937aedfe763);
#
#
#
#         marker_8ab9824194bd7211c4946ac2df7e4bdf.bindPopup(popup_f5fc89f2634050376fbfb20f81d3f3de)
#         ;
#
#
#
#
#             var marker_defed842272a68e8205e96626435e47d = L.marker(
#                 [37.5407625, 127.0793428],
#                 {}

# %%
seoul_map.save('./output/seoul_colleges.html')
