# %% [raw]
# 4.산점도 그래프

# %% [raw]
# 서로다른 두 연속성 변수 사이의 관계를 나타내며 연속성 변수의 상관성을 확인할떄 산점도 그래프를 사용
# 예를 들어 나이와 소득에 대한 상호 관련성 파악등에 유용하게 사용되는데 두변수 간의 상관 관계를 개략적으로 파악할수있기때문
# 산점도에 표시되는 각 점들은 자료의 관측값을 의미하고 각 점의 위치는 관측값이 가지는 x축 y축 변수의 값으로 결정

# %%
# 공공 데이터포탈 에서 다운로드한 2020년 건강검진 일부 데이터 health_screenings_2020.xlsx를
# 이용하여 산점도 그래프를 표현

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('../Numpy/input/health_screenings_2020.xlsx')
data.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0  2020         11       1        10     175      65   92.0       1.0
# 1  2020         11       2        15     150      60   85.0       0.5
# 2  2020         41       2        15     155      60   80.0       0.4
# 3  2020         41       1         9     165      60   83.0       1.0
# 4  2020         31       1         9     160      55   78.0       1.2
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# 0        1.0        1.0  ...    0.8  20.0  22.0  25.0        1         2
# 1        1.0        1.0  ...    0.6  35.0  22.0  16.0        1         1
# 2        0.5        1.0  ...    0.7  29.0  22.0  23.0        1         1
# 3        0.7        1.0  ...    0.9  22.0  22.0  17.0        2         1
# 4        1.2        1.0  ...    1.0  27.0  22.0  20.0        2         2
#
#    oral_check  dental_caries  tartar  open_date
# 0           0            NaN     NaN   20210929
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999465 entries, 0 to 999464
# Data columns (total 30 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   year           999465 non-null  int64
#  1   city_code      999465 non-null  int64
#  2   gender         999465 non-null  int64
#  3   age_code       999465 non-null  int64
#  4   height         999465 non-null  int64
#  5   weight         999465 non-null  int64
#  6   waist          999465 non-null  float64
#  7   eye_left       999231 non-null  float64
#  8   eye_right      999234 non-null  float64
#  9   hear_left      999271 non-null  float64
#  10  hear_right     999274 non-null  float64
#  11  systolic       999448 non-null  float64
#  12  diastolic      999448 non-null  float64
#  13  blood_sugar    999463 non-null  float64
#  14  cholesterol    999421 non-null  float64
#  15  triglycerides  999465 non-null  float64
#  16  HDL            999451 non-null  float64
# ...

# %%
df1 = data.iloc[:10000]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           10000 non-null  int64
#  1   city_code      10000 non-null  int64
#  2   gender         10000 non-null  int64
#  3   age_code       10000 non-null  int64
#  4   height         10000 non-null  int64
#  5   weight         10000 non-null  int64
#  6   waist          10000 non-null  float64
#  7   eye_left       9997 non-null   float64
#  8   eye_right      9998 non-null   float64
#  9   hear_left      9997 non-null   float64
#  10  hear_right     9997 non-null   float64
#  11  systolic       9998 non-null   float64
#  12  diastolic      9998 non-null   float64
#  13  blood_sugar    10000 non-null  float64
#  14  cholesterol    10000 non-null  float64
#  15  triglycerides  10000 non-null  float64
#  16  HDL            10000 non-null  float64
# ...

# %%
heigth_data = df1['height'] # 키데이터만 가져와 height_data에 저장
weight_data = df1['weight']  # 키데터만 가져와 weight_data에 저장
heigth_data.head()
# Out:
# 0    175
# 1    150
# 2    155
# 3    165
# 4    160
# Name: height, dtype: int64

# %%
plt.figure(figsize=(10, 4)) # 그래프 크기를 지정\
plt.scatter(heigth_data, weight_data)
plt.title('2020 Health Screenings Scatter Graph')
plt.xlabel('Height')
plt.ylabel('weight')
plt.show()

# %%
# 2) 그룹 산점도 그래프 그리기
# 누적 산점도 그래프를 그리는 것은 기존 산점도 그래프위에 산점도 그래프를 하나 더 그리는 형식

# HDL, LDL, cholesterol 데이터를 가져와 각각의 변수에 저장
HDL_data = df1['HDL']
LDL_data = df1['LDL']
cholesterol_data = df1['cholesterol']

plt.figure(figsize=(10, 6))

plt.scatter(cholesterol_data, LDL_data, color='r', edgecolors='w', label='Cholesterol*LDL')
plt.scatter(HDL_data, cholesterol_data, color='g', edgecolors='w', label='HDL*Cholesterol')
plt.scatter(HDL_data, LDL_data, color='b', edgecolors='w', label='HDL*LDL')

plt.title('2020 Health Screenings Group Scatter Graph')
plt.xlim(-50, 500)
plt.ylim(-50, 500)
plt.legend()
plt.show()
